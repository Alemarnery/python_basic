# %%
def frist_fun():
    print("funcion!")

# %%
def number_squarter_vust(number, power):
    print(number**power)

# %%
number_squarter_vust(5,3)
# Out:
# 125

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Multiples numeros dentro de la funcion
