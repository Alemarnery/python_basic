# %% [markdown]
# Python Collections (Arrays)
# There are four collection data types in the Python programming language:
#
# List is a collection which is ordered and changeable. Allows duplicate members. []
#
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members. ()
#
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members. {}
#
# Dictionary is a collection which is ordered** and changeable. No duplicate members. thisdict={
#     "llave" : "value",
#     "llave" : "value",
#     "llave" : "value",
# }

# %%
#Data types

#integer
type(-12+100)
# Out:
# int

# %%
#float
type(1+1.56)
# Out:
# float

# %%
#Boolean
type(False)
# Out:
# bool

# %%
1>5
# Out:
# False

# %%
#string

'Single Quote'
"Double Quote"
"""Triple Quote"""
# Out:
# 'Triple Quote'

# %%
a = "Hello Wordl!"

print(a[:5] )
# Out:
# Hello

# %% [markdown]
# List

# %%
a = ["a",3,6]

# %%
#Tuple

#Utilizan los tuple para los datos QUE NUNCA VAN A CAMBIAR no son muteables
tuple_scoops = (1,2,5,6)
tuple_scoops
type(tuple_scoops)
# Out:
# tuple

# %% [markdown]
# Set, para los valores unicos.
#
# |, &, - . Me da un valor distinto.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
#Sets

#unique values

daily_prints= {1,2,3}
